# %%
import pandas as pd

from settings import TRAIN_DATA_PATH

# %%
df = pd.read_csv(TRAIN_DATA_PATH)

df.head()
# Out:
#   Sex  Length  Diameter  Height  Whole weight  Shucked weight  Viscera weight  \
# 0   F   0.525     0.430   0.135        0.8435          0.4325          0.1800
# 1   I   0.430     0.325   0.100        0.3645          0.1575          0.0825
# 2   M   0.455     0.350   0.105        0.4160          0.1625          0.0970
# 3   M   0.205     0.155   0.045        0.0425          0.0170          0.0055
# 4   F   0.590     0.465   0.160        1.1005          0.5060          0.2525
#
#    Shell weight  Rings
# 0        0.1815      9
# 1        0.1050      7
# 2        0.1450     11
# 3        0.0155      7
# 4        0.2950     13
